# %% [markdown]
# # Đề kiểm tra lập trình nhập môn phân tích dữ liệu và học sâu

# %% [markdown]
# ### Sinh viên không được phép sử dụng internet
# ### Sinh viên sau khi làm bài xong xuất ra file PDF đồng thời nộp lên Fit-lab và push lên git-hub
# ### Sinh viên làm bắt đầu làm bài từ 15h40 - 18h00

# %%
# Họ và Tên: Thai Quoc Bao
# MSSV: 207CT09955

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
#Bước 1: Load data
def load_dataset():
    X, y = load_iris(return_X_y=True)
    X = X[y!=2]
    y = y[y!=2]
    return X,y
#Điền ở đây
#X,y = 
#print( , )
# Out:
# (100, 4) (100,)

# %% [markdown]
# Kết quả: (100, 4) (100,)

# %%
#Trực quan hóa dữ liệu data
#Điền code ở đây

# %% [markdown]
# Kết quả

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Bước 2: Định nghĩa mô hình hồi quy logistic bằng PyTorch
class LogisticRegressTorch(nn.Module):
    def __init__(self, n_features):
        super(LogisticRegressTorch, self).__init__()
        #Điền ở đây theo comment                # tạo một lớp tuyến tính (nn.Linear) với n_features đầu vào và 1 đầu ra
    
    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
# Bước 3: Định nghĩa lớp dữ liệu
class IrisTorch(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)
    
    def __len__(self):
        return  #Điền ở đây theo comment            #trả về số lượng mẫu trong tập dữ liệu (số lượng hàng trong self.X)
    
    def __getitem__(self, idx):
        return  #Điền ở đây theo comment            #trả về một cặp đặc trưng và nhãn tương ứng với chỉ số idx

# %%
# Tạo dữ liệu
dataset =

# %%
# Bước 4: Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra bằng cách chia ngẫu nhiên 70,30.
train_size =                                               #70%
test_size =                                                #30%
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Tạo DataLoader
batch_size = 64
train_loader = 
test_loader =

# %%
# Bước 5: Định nghĩa criterion và optimizer
n_features = X.shape[1]
model = 
criterion = 
optimizer =

# %%
# Huấn luyện mô hình
n_epochs = 200
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(n_epochs):
    model.train()
    train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
    
    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)
    
    # Đánh giá trên tập kiểm tra
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item() * inputs.size(0)
            
            predicted = (outputs >= 0.5).float()
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    
    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    
    accuracy = correct / total
    test_accuracies.append(accuracy)
    
    print(f'Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100, Train Loss: 1.5363, Test Loss: 1.1464, Test Accuracy: 0.5667
# Epoch 2/100, Train Loss: 1.3642, Test Loss: 0.9990, Test Accuracy: 0.5667
# Epoch 3/100, Train Loss: 1.1826, Test Loss: 0.8553, Test Accuracy: 0.5667
# Epoch 4/100, Train Loss: 1.0041, Test Loss: 0.7488, Test Accuracy: 0.5667
# Epoch 5/100, Train Loss: 0.8650, Test Loss: 0.6726, Test Accuracy: 0.5667
# Epoch 6/100, Train Loss: 0.7584, Test Loss: 0.6448, Test Accuracy: 0.5667
# Epoch 7/100, Train Loss: 0.7119, Test Loss: 0.6277, Test Accuracy: 0.5667
# Epoch 8/100, Train Loss: 0.6748, Test Loss: 0.6201, Test Accuracy: 0.5667
# Epoch 9/100, Train Loss: 0.6613, Test Loss: 0.6153, Test Accuracy: 0.6000
# Epoch 10/100, Train Loss: 0.6459, Test Loss: 0.6177, Test Accuracy: 0.8333
# Epoch 11/100, Train Loss: 0.6331, Test Loss: 0.6089, Test Accuracy: 0.9000
# Epoch 12/100, Train Loss: 0.6254, Test Loss: 0.6007, Test Accuracy: 0.9000
# Epoch 13/100, Train Loss: 0.6178, Test Loss: 0.5932, Test Accuracy: 0.9000
# Epoch 14/100, Train Loss: 0.6107, Test Loss: 0.5912, Test Accuracy: 1.0000
# Epoch 15/100, Train Loss: 0.6030, Test Loss: 0.5763, Test Accuracy: 0.9667
# Epoch 16/100, Train Loss: 0.5958, Test Loss: 0.5755, Test Accuracy: 1.0000
# Epoch 17/100, Train Loss: 0.5881, Test Loss: 0.5733, Test Accuracy: 1.0000
# Epoch 18/100, Train Loss: 0.5812, Test Loss: 0.5642, Test Accuracy: 1.0000
# Epoch 19/100, Train Loss: 0.5738, Test Loss: 0.5550, Test Accuracy: 1.0000
# Epoch 20/100, Train Loss: 0.5664, Test Loss: 0.5468, Test Accuracy: 1.0000
# Epoch 21/100, Train Loss: 0.5599, Test Loss: 0.5523, Test Accuracy: 1.0000
# Epoch 22/100, Train Loss: 0.5544, Test Loss: 0.5473, Test Accuracy: 1.0000
# Epoch 23/100, Train Loss: 0.5480, Test Loss: 0.5246, Test Accuracy: 1.0000
# Epoch 24/100, Train Loss: 0.5392, Test Loss: 0.5174, Test Accuracy: 1.0000
# Epoch 25/100, Train Loss: 0.5327, Test Loss: 0.5109, Test Accuracy: 1.0000
# Epoch 26/100, Train Loss: 0.5268, Test Loss: 0.5217, Test Accuracy: 1.0000
# Epoch 27/100, Train Loss: 0.5222, Test Loss: 0.5116, Test Accuracy: 1.0000
# Epoch 28/100, Train Loss: 0.5157, Test Loss: 0.5163, Test Accuracy: 1.0000
# Epoch 29/100, Train Loss: 0.5121, Test Loss: 0.4975, Test Accuracy: 1.0000
# Epoch 30/100, Train Loss: 0.5035, Test Loss: 0.5023, Test Accuracy: 1.0000
# Epoch 31/100, Train Loss: 0.5000, Test Loss: 0.4906, Test Accuracy: 1.0000
# Epoch 32/100, Train Loss: 0.4931, Test Loss: 0.4876, Test Accuracy: 1.0000
# Epoch 33/100, Train Loss: 0.4880, Test Loss: 0.4780, Test Accuracy: 1.0000
# Epoch 34/100, Train Loss: 0.4815, Test Loss: 0.4604, Test Accuracy: 1.0000
# Epoch 35/100, Train Loss: 0.4755, Test Loss: 0.4592, Test Accuracy: 1.0000
# Epoch 36/100, Train Loss: 0.4700, Test Loss: 0.4497, Test Accuracy: 1.0000
# Epoch 37/100, Train Loss: 0.4656, Test Loss: 0.4487, Test Accuracy: 1.0000
# Epoch 38/100, Train Loss: 0.4602, Test Loss: 0.4434, Test Accuracy: 1.0000
# Epoch 39/100, Train Loss: 0.4555, Test Loss: 0.4386, Test Accuracy: 1.0000
# Epoch 40/100, Train Loss: 0.4511, Test Loss: 0.4425, Test Accuracy: 1.0000
# Epoch 41/100, Train Loss: 0.4468, Test Loss: 0.4351, Test Accuracy: 1.0000
# Epoch 42/100, Train Loss: 0.4417, Test Loss: 0.4250, Test Accuracy: 1.0000
# Epoch 43/100, Train Loss: 0.4369, Test Loss: 0.4206, Test Accuracy: 1.0000
# Epoch 44/100, Train Loss: 0.4327, Test Loss: 0.4155, Test Accuracy: 1.0000
# Epoch 45/100, Train Loss: 0.4284, Test Loss: 0.4109, Test Accuracy: 1.0000
# Epoch 46/100, Train Loss: 0.4241, Test Loss: 0.4072, Test Accuracy: 1.0000
# Epoch 47/100, Train Loss: 0.4199, Test Loss: 0.4103, Test Accuracy: 1.0000
# Epoch 48/100, Train Loss: 0.4158, Test Loss: 0.4043, Test Accuracy: 1.0000
# Epoch 49/100, Train Loss: 0.4114, Test Loss: 0.3986, Test Accuracy: 1.0000
# Epoch 50/100, Train Loss: 0.4073, Test Loss: 0.3982, Test Accuracy: 1.0000
# Epoch 51/100, Train Loss: 0.4037, Test Loss: 0.3972, Test Accuracy: 1.0000
# Epoch 52/100, Train Loss: 0.4003, Test Loss: 0.3956, Test Accuracy: 1.0000
# Epoch 53/100, Train Loss: 0.3969, Test Loss: 0.3932, Test Accuracy: 1.0000
# Epoch 54/100, Train Loss: 0.3933, Test Loss: 0.3813, Test Accuracy: 1.0000
# Epoch 55/100, Train Loss: 0.3880, Test Loss: 0.3768, Test Accuracy: 1.0000
# Epoch 56/100, Train Loss: 0.3843, Test Loss: 0.3721, Test Accuracy: 1.0000
# Epoch 57/100, Train Loss: 0.3808, Test Loss: 0.3711, Test Accuracy: 1.0000
# Epoch 58/100, Train Loss: 0.3775, Test Loss: 0.3745, Test Accuracy: 1.0000
# Epoch 59/100, Train Loss: 0.3750, Test Loss: 0.3694, Test Accuracy: 1.0000
# Epoch 60/100, Train Loss: 0.3714, Test Loss: 0.3686, Test Accuracy: 1.0000
# Epoch 61/100, Train Loss: 0.3692, Test Loss: 0.3773, Test Accuracy: 1.0000
# Epoch 62/100, Train Loss: 0.3693, Test Loss: 0.3728, Test Accuracy: 1.0000
# Epoch 63/100, Train Loss: 0.3655, Test Loss: 0.3690, Test Accuracy: 1.0000
# Epoch 64/100, Train Loss: 0.3617, Test Loss: 0.3555, Test Accuracy: 1.0000
# Epoch 65/100, Train Loss: 0.3553, Test Loss: 0.3457, Test Accuracy: 1.0000
# Epoch 66/100, Train Loss: 0.3508, Test Loss: 0.3417, Test Accuracy: 1.0000
# Epoch 67/100, Train Loss: 0.3478, Test Loss: 0.3377, Test Accuracy: 1.0000
# Epoch 68/100, Train Loss: 0.3447, Test Loss: 0.3372, Test Accuracy: 1.0000
# Epoch 69/100, Train Loss: 0.3419, Test Loss: 0.3297, Test Accuracy: 1.0000
# Epoch 70/100, Train Loss: 0.3388, Test Loss: 0.3298, Test Accuracy: 1.0000
# Epoch 71/100, Train Loss: 0.3359, Test Loss: 0.3258, Test Accuracy: 1.0000
# Epoch 72/100, Train Loss: 0.3331, Test Loss: 0.3257, Test Accuracy: 1.0000
# Epoch 73/100, Train Loss: 0.3305, Test Loss: 0.3251, Test Accuracy: 1.0000
# Epoch 74/100, Train Loss: 0.3280, Test Loss: 0.3212, Test Accuracy: 1.0000
# Epoch 75/100, Train Loss: 0.3252, Test Loss: 0.3237, Test Accuracy: 1.0000
# Epoch 76/100, Train Loss: 0.3233, Test Loss: 0.3185, Test Accuracy: 1.0000
# Epoch 77/100, Train Loss: 0.3202, Test Loss: 0.3174, Test Accuracy: 1.0000
# Epoch 78/100, Train Loss: 0.3178, Test Loss: 0.3074, Test Accuracy: 1.0000
# Epoch 79/100, Train Loss: 0.3142, Test Loss: 0.3026, Test Accuracy: 1.0000
# Epoch 80/100, Train Loss: 0.3118, Test Loss: 0.2982, Test Accuracy: 1.0000
# Epoch 81/100, Train Loss: 0.3096, Test Loss: 0.2960, Test Accuracy: 1.0000
# Epoch 82/100, Train Loss: 0.3072, Test Loss: 0.2940, Test Accuracy: 1.0000
# Epoch 83/100, Train Loss: 0.3046, Test Loss: 0.2922, Test Accuracy: 1.0000
# Epoch 84/100, Train Loss: 0.3022, Test Loss: 0.2897, Test Accuracy: 1.0000
# Epoch 85/100, Train Loss: 0.2999, Test Loss: 0.2874, Test Accuracy: 1.0000
# Epoch 86/100, Train Loss: 0.2975, Test Loss: 0.2852, Test Accuracy: 1.0000
# Epoch 87/100, Train Loss: 0.2958, Test Loss: 0.2782, Test Accuracy: 1.0000
# Epoch 88/100, Train Loss: 0.2954, Test Loss: 0.2783, Test Accuracy: 1.0000
# Epoch 89/100, Train Loss: 0.2919, Test Loss: 0.2739, Test Accuracy: 1.0000
# Epoch 90/100, Train Loss: 0.2910, Test Loss: 0.2724, Test Accuracy: 1.0000
# Epoch 91/100, Train Loss: 0.2885, Test Loss: 0.2696, Test Accuracy: 1.0000
# Epoch 92/100, Train Loss: 0.2871, Test Loss: 0.2682, Test Accuracy: 1.0000
# Epoch 93/100, Train Loss: 0.2843, Test Loss: 0.2680, Test Accuracy: 1.0000
# Epoch 94/100, Train Loss: 0.2811, Test Loss: 0.2666, Test Accuracy: 1.0000
# Epoch 95/100, Train Loss: 0.2789, Test Loss: 0.2651, Test Accuracy: 1.0000
# Epoch 96/100, Train Loss: 0.2768, Test Loss: 0.2624, Test Accuracy: 1.0000
# Epoch 97/100, Train Loss: 0.2751, Test Loss: 0.2629, Test Accuracy: 1.0000
# Epoch 98/100, Train Loss: 0.2724, Test Loss: 0.2650, Test Accuracy: 1.0000
# Epoch 99/100, Train Loss: 0.2702, Test Loss: 0.2648, Test Accuracy: 1.0000
# Epoch 100/100, Train Loss: 0.2684, Test Loss: 0.2602, Test Accuracy: 1.0000

# %%
# Vẽ biểu đồ loss và accuracy

# %% [markdown]
# #Kết quả:

# %% [markdown]
# ![image.png](attachment:image.png)
